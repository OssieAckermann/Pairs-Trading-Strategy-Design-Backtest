# %%
import import_ipynb
import warnings
warnings.filterwarnings('ignore')
from colorit import *
init_colorit()

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Part 1: Data Inspection

# %%
coint_prices = pd.read_csv('data.csv',index_col = 'Date')
coint_prices.head(10)
# Out:
#                  BABA          FB
# Date
# 2016-01-04  76.690002  102.220001
# 2016-01-05  78.629997  102.730003
# 2016-01-06  77.330002  102.970001
# 2016-01-07  72.720001   97.919998
# 2016-01-08  70.800003   97.330002
# 2016-01-11  69.919998   97.510002
# 2016-01-12  72.680000   99.370003
# 2016-01-13  70.290001   95.440002
# 2016-01-14  72.250000   98.370003
# 2016-01-15  69.589996   94.970001

# %%
coint_prices.plot(figsize = (10,6), 
                  fontsize = 12,)
plt.title('Facebook vs Alibaba',
          fontsize = 20,
         color = '#E64848')
# Out:
# Text(0.5, 1.0, 'Facebook vs Alibaba')

# %%
prices_diff = coint_prices.BABA - coint_prices.FB
prices_diff.plot(figsize = (10,6), 
                  fontsize = 12,
                color = '#E64848')
plt.title('Alibaba - Facebook price difference',
          fontsize = 20,
         color = '#E64848')
# Out:
# Text(0.5, 1.0, 'Alibaba - Facebook price difference')

# %%
coint_prices = coint_prices/coint_prices.iloc[0]
coint_prices.plot(figsize = (10,6), 
                  fontsize = 12,)
plt.title('Facebook vs Alibaba',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Facebook vs Alibaba')

# %%
# return

# %%
returns = np.log(coint_prices).diff().dropna()
returns.head()
# Out:
#                 BABA        FB
# Date
# 2016-01-05  0.024982  0.004977
# 2016-01-06 -0.016671  0.002333
# 2016-01-07 -0.061466 -0.050287
# 2016-01-08 -0.026757 -0.006044
# 2016-01-11 -0.012507  0.001848

# %%
returns.plot(figsize = (16,9),subplots = True, linewidth = 0.8)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f9c7caf0c10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f9c7cb432b0>],
#       dtype=object)

# %%
returns
# Out:
#                 BABA        FB
# Date
# 2016-01-05  0.024982  0.004977
# 2016-01-06 -0.016671  0.002333
# 2016-01-07 -0.061466 -0.050287
# 2016-01-08 -0.026757 -0.006044
# 2016-01-11 -0.012507  0.001848
# ...              ...       ...
# 2020-11-23 -0.002330 -0.004720
# 2020-11-24  0.035817  0.031139
# 2020-11-25 -0.008033 -0.004814
# 2020-11-27 -0.004475  0.008023
# 2020-11-30 -0.048617 -0.003028
#
# [1236 rows x 2 columns]

# %%
from utility import VAR
# Out:
# importing Jupyter notebook from utility.ipynb

# %%
model = VAR(returns, lag = 1)
model.report()
# Out:
#               Estimate Coefficient           SD of Estimate            \
#                               BABA        FB           BABA        FB
# (Lag_1, BABA)             0.026525 -0.030452       0.032299  0.032653
# (Lag_1, FB)              -0.045617 -0.078142       0.031753  0.032102
# constant                  0.001008  0.000901       0.000588  0.000595
#
#               t-Statistic
#                      BABA        FB
# (Lag_1, BABA)    0.821254 -0.932594
# (Lag_1, FB)     -1.436612 -2.434177
# constant         1.712616  1.515292

# %%
model.p_value < 0.05
# Out:
#                 BABA     FB
# (Lag_1, BABA)  False  False
# (Lag_1, FB)    False   True
# constant       False  False

# %%
model.IC(lag = 10,)
# Out:
# <style  type="text/css" >
#     #T_462ba95c_4c86_11eb_9b98_9801a7d858a3row0_col0 {
#             color:  red;
#         }    #T_462ba95c_4c86_11eb_9b98_9801a7d858a3row0_col1 {
#             color:  red;
#         }</style><table id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AIC</th>        <th class="col_heading level0 col1" >BIC</th>    </tr>    <tr>        <th class="index_name level0" >Lag</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row0_col0" class="data row0 col0" >-15.740571</td>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row0_col1" class="data row0 col1" >-15.715718</td>
#             </tr>
#             <tr>
#                         <th id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row1_col0" class="data row1 col0" >-15.736774</td>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row1_col1" class="data row1 col1" >-15.695353</td>
#             </tr>
#             <tr>
#                         <th id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row2_col0" class="data row2 col0" >-15.738975</td>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row2_col1" class="data row2 col1" >-15.680986</td>
#             </tr>
#             <tr>
#                         <th id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row3_col0" class="data row3 col0" >-15.734060</td>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row3_col1" class="data row3 col1" >-15.659503</td>
#             </tr>
#             <tr>
#                         <th id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row4_col0" class="data row4 col0" >-15.730489</td>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row4_col1" class="data row4 col1" >-15.639363</td>
#             </tr>
#             <tr>
#                         <th id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row5_col0" class="data row5 col0" >-15.731600</td>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row5_col1" class="data row5 col1" >-15.623906</td>
#             </tr>
#             <tr>
#                         <th id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row6_col0" class="data row6 col0" >-15.733265</td>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row6_col1" class="data row6 col1" >-15.609002</td>
#             </tr>
#             <tr>
#                         <th id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row7_col0" class="data row7 col0" >-15.739999</td>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row7_col1" class="data row7 col1" >-15.599167</td>
#             </tr>
#             <tr>
#                         <th id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3level0_row8" class="row_heading level0 row8" >9</th>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row8_col0" class="data row8 col0" >-15.737229</td>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row8_col1" class="data row8 col1" >-15.579829</td>
#             </tr>
#             <tr>
#                         <th id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3level0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row9_col0" class="data row9 col0" >-15.737267</td>
#                         <td id="T_462ba95c_4c86_11eb_9b98_9801a7d858a3row9_col1" class="data row9 col1" >-15.563299</td>
#             </tr>
#     </tbody></table>

# %%
model.stability()
# Out:
# Stability status: [o] STABLE

# %% [markdown]
# # Part 2: Cointegration

# %%
coint_prices = pd.read_csv('data.csv',index_col = 'Date')
FB = pd.DataFrame(coint_prices['FB'])
BABA = pd.DataFrame(coint_prices['BABA'])

# %%
coint_prices.plot( figsize = (16,6),
                  color = ['#E64848','#476995'],
                  subplots = True,
                 title = 'Daily Price',)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f9c7f616970>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f9c7f67dd30>],
#       dtype=object)

# %% [markdown]
# # Engle Granger step 1

# %%
from utility import LinearRegression as LR

# %%
model = LR(x = BABA, y = FB) 
model.report()
# Out:
#          Estimate Coefficient SD of Estimate t-Statistic
#                            FB             FB          FB
# BABA                 0.729003       0.006459  112.858842
# constant            52.451564       1.105572   47.442911

# %%
#b_coint, constant
model.coef
# Out:
#                  FB
# BABA       0.729003
# constant  52.451564

# %%
residuals = pd.DataFrame(model.error.reshape(1,1237)[0],
                         index = BABA.index,
                         columns = ['Residual(FB)'])
residuals.head()
# Out:
#             Residual(FB)
# Date
# 2016-01-04     -6.138810
# 2016-01-05     -7.043070
# 2016-01-06     -5.855372
# 2016-01-07     -7.544670
# 2016-01-08     -6.734982

# %%
residuals.plot(figsize = (16,6),
              color = '#E64848',
              title = 'Residual',
              fontsize = 12)

# %%
from utility import ADF

# %%
adf_test = ADF(residuals)
adf_test.report()
# Out:
# The T-value is [-4.6388966] which is lower than -3.45
# [*]We reject the  𝐻0  hypothesis of unit root. The residuals are stationary.
# <style  type="text/css" >
#     #T_46cad900_4c86_11eb_9b98_9801a7d858a3row0_col0 {
#             color:  black;
#         }    #T_46cad900_4c86_11eb_9b98_9801a7d858a3row0_col1 {
#             color:  black;
#         }    #T_46cad900_4c86_11eb_9b98_9801a7d858a3row0_col2 {
#             color:  red;
#         }    #T_46cad900_4c86_11eb_9b98_9801a7d858a3row1_col0 {
#             color:  black;
#         }    #T_46cad900_4c86_11eb_9b98_9801a7d858a3row1_col1 {
#             color:  black;
#         }    #T_46cad900_4c86_11eb_9b98_9801a7d858a3row1_col2 {
#             color:  black;
#         }    #T_46cad900_4c86_11eb_9b98_9801a7d858a3row2_col0 {
#             color:  black;
#         }    #T_46cad900_4c86_11eb_9b98_9801a7d858a3row2_col1 {
#             color:  black;
#         }    #T_46cad900_4c86_11eb_9b98_9801a7d858a3row2_col2 {
#             color:  black;
#         }</style><table id="T_46cad900_4c86_11eb_9b98_9801a7d858a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Estimate Coefficient</th>        <th class="col_heading level0 col1" >SD of Estimate</th>        <th class="col_heading level0 col2" >t-Statistic</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >(ΔResidual(FB))</th>        <th class="col_heading level1 col1" >(ΔResidual(FB))</th>        <th class="col_heading level1 col2" >(ΔResidual(FB))</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_46cad900_4c86_11eb_9b98_9801a7d858a3level0_row0" class="row_heading level0 row0" >(Lag 1, Residual(FB))</th>
#                         <td id="T_46cad900_4c86_11eb_9b98_9801a7d858a3row0_col0" class="data row0 col0" >-0.036935</td>
#                         <td id="T_46cad900_4c86_11eb_9b98_9801a7d858a3row0_col1" class="data row0 col1" >0.007962</td>
#                         <td id="T_46cad900_4c86_11eb_9b98_9801a7d858a3row0_col2" class="data row0 col2" >-4.638897</td>
#             </tr>
#             <tr>
#                         <th id="T_46cad900_4c86_11eb_9b98_9801a7d858a3level0_row1" class="row_heading level0 row1" >(Lag 1, ΔResidual(FB))</th>
#                         <td id="T_46cad900_4c86_11eb_9b98_9801a7d858a3row1_col0" class="data row1 col0" >0.015089</td>
#                         <td id="T_46cad900_4c86_11eb_9b98_9801a7d858a3row1_col1" class="data row1 col1" >0.028612</td>
#                         <td id="T_46cad900_4c86_11eb_9b98_9801a7d858a3row1_col2" class="data row1 col2" >0.527379</td>
#             </tr>
#             <tr>
#                         <th id="T_46cad900_4c86_11eb_9b98_9801a7d858a3level0_row2" class="row_heading level0 row2" >constant</th>
#                         <td id="T_46cad900_4c86_11eb_9b98_9801a7d858a3row2_col0" class="data row2 col0" >0.030886</td>
#                         <td id="T_46cad900_4c86_11eb_9b98_9801a7d858a3row2_col1" class="data row2 col1" >0.099154</td>
#                         <td id="T_46cad900_4c86_11eb_9b98_9801a7d858a3row2_col2" class="data row2 col2" >0.311499</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Engle Granger step 2
#
#
# $$ {  ΔPA_{𝑡}=𝜑ΔPB_{𝑡} − (1−𝛼)𝑒ˆ𝑡−1+𝜀_{𝑡} }$$
#
# $$ { ΔFB𝑡 = 𝜑ΔBABA_{𝑡} −(1−𝛼)CointResidual(FB \; on \; BABA_{𝑡−1}) + 𝜀_{t} }$$

# %%
Δy = pd.DataFrame(FB).diff().dropna().add_prefix('Δ')
Δx = pd.DataFrame(BABA).diff().dropna().add_prefix('Δ')

X = Δx.join(residuals.shift(1).dropna().add_prefix('(Lag 1, ').add_suffix(')'))

model = LR(X, Δy,add_const = False)
model.report()
#step_2 = linear_regression(Δy, X, '')
#step_2.fit
# Out:
#                       Estimate Coefficient SD of Estimate t-Statistic
#                                        ΔFB            ΔFB         ΔFB
# ΔBABA                             0.492035       0.025909   18.991042
# (Lag 1, Residual(FB))            -0.033257       0.007627   -4.360584

# %%
model.p_value < 0.05
# Out:
#                         ΔFB
# ΔBABA                  True
# (Lag 1, Residual(FB))  True
