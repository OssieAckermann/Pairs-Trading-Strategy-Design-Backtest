# %%
import import_ipynb
import warnings
warnings.filterwarnings('ignore')
from colorit import *
init_colorit()

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
 
import pyfolio as pf

# %% [markdown]
# # Data Inspection

# %%
datafile = 'data.csv'
coint_prices = pd.read_csv(datafile,index_col = 'Date')
coint_prices.tail(10)
# Out:
#                   BABA          FB
# Date
# 2020-11-16  258.309998  278.959991
# 2020-11-17  256.799988  275.000000
# 2020-11-18  255.830002  271.970001
# 2020-11-19  259.890015  272.940002
# 2020-11-20  270.739990  269.700012
# 2020-11-23  270.109985  268.429993
# 2020-11-24  279.959991  276.920013
# 2020-11-25  277.720001  275.589996
# 2020-11-27  276.480011  277.809998
# 2020-11-30  263.359985  276.970001

# %%
coint_prices.plot(figsize = (10,6), 
                  fontsize = 12,
                 color = ['#F55C10','#0A63F5'],alpha = 0.7)
plt.title('Facebook vs Alibaba',
          fontsize = 20,
         color = '#E64848')
plt.grid(True)

# %%
prices_diff = coint_prices.BABA - coint_prices.FB
prices_diff.plot(figsize = (10,6), 
                  fontsize = 12,
                color = 'black',
                alpha = 0.7)
plt.title('Alibaba - Facebook price difference',
          fontsize = 15,
         color = '#E64848')
plt.grid(True)

# %%
coint_prices = coint_prices/coint_prices.iloc[0]
coint_prices.plot(figsize = (10,6), 
                  fontsize = 12,
                 color = ['#F55C10','#0A63F5'],
                  alpha = 0.7)
plt.title('Adjusted Facebook vs Alibaba',fontsize = 20,color = '#E64848')
plt.grid(True)

# %%
# return

# %%
returns = np.log(coint_prices).diff().dropna()
returns.head()
# Out:
#                 BABA        FB
# Date
# 2018-01-03  0.001904  0.017756
# 2018-01-04  0.009251 -0.001843
# 2018-01-05  0.026515  0.013579
# 2018-01-08 -0.001942  0.007624
# 2018-01-09  0.002466 -0.002180

# %%
returns.plot(figsize = (16,9),subplots = True, linewidth = 0.8)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1dee10e20>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1def8dee0>],
#       dtype=object)

# %%
returns
# Out:
#                 BABA        FB
# Date
# 2018-01-03  0.001904  0.017756
# 2018-01-04  0.009251 -0.001843
# 2018-01-05  0.026515  0.013579
# 2018-01-08 -0.001942  0.007624
# 2018-01-09  0.002466 -0.002180
# ...              ...       ...
# 2020-11-23 -0.002330 -0.004720
# 2020-11-24  0.035817  0.031139
# 2020-11-25 -0.008033 -0.004814
# 2020-11-27 -0.004475  0.008023
# 2020-11-30 -0.048617 -0.003028
#
# [733 rows x 2 columns]

# %%
from utility import VAR
# Out:
# importing Jupyter notebook from utility.ipynb

# %%
model = VAR(returns, lag = 1)
model.report()
# Out:
#               Estimate Coefficient           SD of Estimate            \
#                               BABA        FB           BABA        FB
# (Lag_1, BABA)             0.045013 -0.030688       0.043083  0.047057
# (Lag_1, FB)              -0.073990 -0.099768       0.039143  0.042752
# constant                  0.000510  0.000652       0.000821  0.000897
#
#               t-Statistic
#                      BABA        FB
# (Lag_1, BABA)    1.044792 -0.652155
# (Lag_1, FB)     -1.890267 -2.333627
# constant         0.620490  0.727090

# %%
model.p_value < 0.05
# Out:
#                 BABA     FB
# (Lag_1, BABA)  False  False
# (Lag_1, FB)    False   True
# constant       False  False

# %%
model.IC(lag = 10,)
# Out:
# <style  type="text/css" >
#     #T_3ae93c60_512e_11eb_9d01_9801a7d858a3row0_col0 {
#             color:  red;
#         }    #T_3ae93c60_512e_11eb_9d01_9801a7d858a3row0_col1 {
#             color:  red;
#         }</style><table id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AIC</th>        <th class="col_heading level0 col1" >BIC</th>    </tr>    <tr>        <th class="index_name level0" >Lag</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row0_col0" class="data row0 col0" >-15.339415</td>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row0_col1" class="data row0 col1" >-15.301785</td>
#             </tr>
#             <tr>
#                         <th id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row1_col0" class="data row1 col0" >-15.332764</td>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row1_col1" class="data row1 col1" >-15.270047</td>
#             </tr>
#             <tr>
#                         <th id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row2_col0" class="data row2 col0" >-15.331255</td>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row2_col1" class="data row2 col1" >-15.243451</td>
#             </tr>
#             <tr>
#                         <th id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row3_col0" class="data row3 col0" >-15.321393</td>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row3_col1" class="data row3 col1" >-15.208503</td>
#             </tr>
#             <tr>
#                         <th id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row4_col0" class="data row4 col0" >-15.312210</td>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row4_col1" class="data row4 col1" >-15.174233</td>
#             </tr>
#             <tr>
#                         <th id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row5_col0" class="data row5 col0" >-15.308782</td>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row5_col1" class="data row5 col1" >-15.145718</td>
#             </tr>
#             <tr>
#                         <th id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row6_col0" class="data row6 col0" >-15.306070</td>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row6_col1" class="data row6 col1" >-15.117920</td>
#             </tr>
#             <tr>
#                         <th id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row7_col0" class="data row7 col0" >-15.309380</td>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row7_col1" class="data row7 col1" >-15.096142</td>
#             </tr>
#             <tr>
#                         <th id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3level0_row8" class="row_heading level0 row8" >9</th>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row8_col0" class="data row8 col0" >-15.303473</td>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row8_col1" class="data row8 col1" >-15.065149</td>
#             </tr>
#             <tr>
#                         <th id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3level0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row9_col0" class="data row9 col0" >-15.300814</td>
#                         <td id="T_3ae93c60_512e_11eb_9d01_9801a7d858a3row9_col1" class="data row9 col1" >-15.037403</td>
#             </tr>
#     </tbody></table>

# %%
model.stability()
# Out:
# Stability status: [o] STABLE

# %% [markdown]
# # Cointegration

# %%
coint_prices = pd.read_csv(datafile, index_col = 'Date')
FB = pd.DataFrame(coint_prices['FB'])
BABA = pd.DataFrame(coint_prices['BABA'])

# %%
coint_prices.plot(figsize = (16,6),
                  color = ['#F55C10','#0A63F5'],
                  subplots = True,
                 title = 'Daily Price',)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1da1a86a0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fc1deabbc70>],
#       dtype=object)

# %% [markdown]
# # Engle Granger
# ## FB - BABA

# %%
from utility import LinearRegression as LR

# %%
model = LR(x = BABA, y = FB) 
model.report()
# Out:
#          Estimate Coefficient SD of Estimate t-Statistic
#                            FB             FB          FB
# BABA                 0.864299       0.013810   62.585632
# constant            24.744947       2.749676    8.999223

# %%
#b_coint, constant
model.coef
# Out:
#                  FB
# BABA       0.864299
# constant  24.744947

# %%
residuals = pd.DataFrame(model.error.reshape(1,len(FB))[0],
                         index = BABA.index,
                         columns = ['Residual(FB - β·BABA)'])
residuals.head()
# Out:
#             Residual(FB - β·BABA)
# Date
# 2018-01-02              -2.053493
# 2018-01-03               0.893997
# 2018-01-04              -0.923957
# 2018-01-05              -2.716797
# 2018-01-08              -0.967018

# %%
residuals.plot(figsize = (16,6),
              color = 'black',alpha = 0.7,
              fontsize = 12,linewidth = 1)
plt.title('Residual(FB - β·BABA)',
         color = '#E64848',
         fontsize = 15)
plt.grid(True)

# %%
from utility import ADF

# %%
adf_test = ADF(residuals)
adf_test.report()
# Out:
# The T-value is [-4.15444074] which is lower than -3.45
# [*]We reject the  𝐻0  hypothesis of unit root. The residuals are stationary.
# <style  type="text/css" >
#     #T_3b82998c_512e_11eb_9d01_9801a7d858a3row0_col0 {
#             color:  black;
#         }    #T_3b82998c_512e_11eb_9d01_9801a7d858a3row0_col1 {
#             color:  black;
#         }    #T_3b82998c_512e_11eb_9d01_9801a7d858a3row0_col2 {
#             color:  red;
#         }    #T_3b82998c_512e_11eb_9d01_9801a7d858a3row1_col0 {
#             color:  black;
#         }    #T_3b82998c_512e_11eb_9d01_9801a7d858a3row1_col1 {
#             color:  black;
#         }    #T_3b82998c_512e_11eb_9d01_9801a7d858a3row1_col2 {
#             color:  black;
#         }    #T_3b82998c_512e_11eb_9d01_9801a7d858a3row2_col0 {
#             color:  black;
#         }    #T_3b82998c_512e_11eb_9d01_9801a7d858a3row2_col1 {
#             color:  black;
#         }    #T_3b82998c_512e_11eb_9d01_9801a7d858a3row2_col2 {
#             color:  black;
#         }</style><table id="T_3b82998c_512e_11eb_9d01_9801a7d858a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Estimate Coefficient</th>        <th class="col_heading level0 col1" >SD of Estimate</th>        <th class="col_heading level0 col2" >t-Statistic</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >(ΔResidual(FB - β·BABA))</th>        <th class="col_heading level1 col1" >(ΔResidual(FB - β·BABA))</th>        <th class="col_heading level1 col2" >(ΔResidual(FB - β·BABA))</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3b82998c_512e_11eb_9d01_9801a7d858a3level0_row0" class="row_heading level0 row0" >(Lag 1, Residual(FB - β·BABA))</th>
#                         <td id="T_3b82998c_512e_11eb_9d01_9801a7d858a3row0_col0" class="data row0 col0" >-0.047907</td>
#                         <td id="T_3b82998c_512e_11eb_9d01_9801a7d858a3row0_col1" class="data row0 col1" >0.011532</td>
#                         <td id="T_3b82998c_512e_11eb_9d01_9801a7d858a3row0_col2" class="data row0 col2" >-4.154441</td>
#             </tr>
#             <tr>
#                         <th id="T_3b82998c_512e_11eb_9d01_9801a7d858a3level0_row1" class="row_heading level0 row1" >(Lag 1, ΔResidual(FB - β·BABA))</th>
#                         <td id="T_3b82998c_512e_11eb_9d01_9801a7d858a3row1_col0" class="data row1 col0" >0.030824</td>
#                         <td id="T_3b82998c_512e_11eb_9d01_9801a7d858a3row1_col1" class="data row1 col1" >0.037194</td>
#                         <td id="T_3b82998c_512e_11eb_9d01_9801a7d858a3row1_col2" class="data row1 col2" >0.828745</td>
#             </tr>
#             <tr>
#                         <th id="T_3b82998c_512e_11eb_9d01_9801a7d858a3level0_row2" class="row_heading level0 row2" >constant</th>
#                         <td id="T_3b82998c_512e_11eb_9d01_9801a7d858a3row2_col0" class="data row2 col0" >0.030233</td>
#                         <td id="T_3b82998c_512e_11eb_9d01_9801a7d858a3row2_col1" class="data row2 col1" >0.164179</td>
#                         <td id="T_3b82998c_512e_11eb_9d01_9801a7d858a3row2_col2" class="data row2 col2" >0.184150</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# $$ {  ΔPA_{𝑡}=𝜑ΔPB_{𝑡} − (1−𝛼)𝑒ˆ𝑡−1+𝜀_{𝑡} }$$
#
# $$ { ΔFB𝑡 = 𝜑ΔBABA_{𝑡} −(1−𝛼)CointResidual(FB \; on \; BABA_{𝑡−1}) + 𝜀_{t} }$$

# %%
Δy = pd.DataFrame(FB).diff().dropna().add_prefix('Δ')
Δx = pd.DataFrame(BABA).diff().dropna().add_prefix('Δ')

X = Δx.join(residuals.shift(1).dropna().add_prefix('(Lag 1, ').add_suffix(')'))

model = LR(X, Δy,add_const = False)
model.report()
# Out:
#                                Estimate Coefficient SD of Estimate t-Statistic
#                                                 ΔFB            ΔFB         ΔFB
# ΔBABA                                      0.510556       0.034257   14.903664
# (Lag 1, Residual(FB - β·BABA))            -0.040760       0.010647   -3.828437

# %%
model.p_value < 0.05
# Out:
#                                  ΔFB
# ΔBABA                           True
# (Lag 1, Residual(FB - β·BABA))  True

# %% [markdown]
# ## BABA - FB

# %%
model = LR(x = FB, y = BABA,add_const = True) 
model.report()
# Out:
#          Estimate Coefficient SD of Estimate t-Statistic
#                          BABA           BABA        BABA
# FB                   0.974831       0.015576   62.585632
# constant             6.633532       3.067732    2.162357

# %%
residuals = pd.DataFrame(model.error.reshape(1,len(BABA))[0],
                         index = BABA.index,
                         columns = ['Residual(BABA - β·FB)'])
residuals.head()
# Out:
#             Residual(BABA - β·FB)
# Date
# 2018-01-02               0.162663
# 2018-01-03              -2.655531
# 2018-01-04              -0.614085
# 2018-01-05               1.919327
# 2018-01-08               0.155331

# %%
residuals.plot(figsize = (16,6),
              color = 'black',alpha = 0.7,
              fontsize = 12,linewidth = 1)
plt.title('Residual(BABA - β·FB)',
          color = '#E64848',
         fontsize = 15)
plt.grid(True)

# %%
adf_test = ADF(residuals)
adf_test.report()
# Out:
# The T-value is [-4.24848594] which is lower than -3.45
# [*]We reject the  𝐻0  hypothesis of unit root. The residuals are stationary.
# <style  type="text/css" >
#     #T_3bd42068_512e_11eb_9d01_9801a7d858a3row0_col0 {
#             color:  black;
#         }    #T_3bd42068_512e_11eb_9d01_9801a7d858a3row0_col1 {
#             color:  black;
#         }    #T_3bd42068_512e_11eb_9d01_9801a7d858a3row0_col2 {
#             color:  red;
#         }    #T_3bd42068_512e_11eb_9d01_9801a7d858a3row1_col0 {
#             color:  black;
#         }    #T_3bd42068_512e_11eb_9d01_9801a7d858a3row1_col1 {
#             color:  black;
#         }    #T_3bd42068_512e_11eb_9d01_9801a7d858a3row1_col2 {
#             color:  black;
#         }    #T_3bd42068_512e_11eb_9d01_9801a7d858a3row2_col0 {
#             color:  black;
#         }    #T_3bd42068_512e_11eb_9d01_9801a7d858a3row2_col1 {
#             color:  black;
#         }    #T_3bd42068_512e_11eb_9d01_9801a7d858a3row2_col2 {
#             color:  black;
#         }</style><table id="T_3bd42068_512e_11eb_9d01_9801a7d858a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Estimate Coefficient</th>        <th class="col_heading level0 col1" >SD of Estimate</th>        <th class="col_heading level0 col2" >t-Statistic</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >(ΔResidual(BABA - β·FB))</th>        <th class="col_heading level1 col1" >(ΔResidual(BABA - β·FB))</th>        <th class="col_heading level1 col2" >(ΔResidual(BABA - β·FB))</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3bd42068_512e_11eb_9d01_9801a7d858a3level0_row0" class="row_heading level0 row0" >(Lag 1, Residual(BABA - β·FB))</th>
#                         <td id="T_3bd42068_512e_11eb_9d01_9801a7d858a3row0_col0" class="data row0 col0" >-0.047918</td>
#                         <td id="T_3bd42068_512e_11eb_9d01_9801a7d858a3row0_col1" class="data row0 col1" >0.011279</td>
#                         <td id="T_3bd42068_512e_11eb_9d01_9801a7d858a3row0_col2" class="data row0 col2" >-4.248486</td>
#             </tr>
#             <tr>
#                         <th id="T_3bd42068_512e_11eb_9d01_9801a7d858a3level0_row1" class="row_heading level0 row1" >(Lag 1, ΔResidual(BABA - β·FB))</th>
#                         <td id="T_3bd42068_512e_11eb_9d01_9801a7d858a3row1_col0" class="data row1 col0" >0.042808</td>
#                         <td id="T_3bd42068_512e_11eb_9d01_9801a7d858a3row1_col1" class="data row1 col1" >0.037176</td>
#                         <td id="T_3bd42068_512e_11eb_9d01_9801a7d858a3row1_col2" class="data row1 col2" >1.151512</td>
#             </tr>
#             <tr>
#                         <th id="T_3bd42068_512e_11eb_9d01_9801a7d858a3level0_row2" class="row_heading level0 row2" >constant</th>
#                         <td id="T_3bd42068_512e_11eb_9d01_9801a7d858a3row2_col0" class="data row2 col0" >-0.013579</td>
#                         <td id="T_3bd42068_512e_11eb_9d01_9801a7d858a3row2_col1" class="data row2 col1" >0.170938</td>
#                         <td id="T_3bd42068_512e_11eb_9d01_9801a7d858a3row2_col2" class="data row2 col2" >-0.079441</td>
#             </tr>
#     </tbody></table>

# %%
Δy = pd.DataFrame(BABA).diff().dropna().add_prefix('Δ')
Δx = pd.DataFrame(FB).diff().dropna().add_prefix('Δ')

X = Δx.join(residuals.shift(1).dropna().add_prefix('(Lag 1, ').add_suffix(')'))

model = LR(X, Δy,add_const = False)
model.report()
# Out:
#                                Estimate Coefficient SD of Estimate t-Statistic
#                                               ΔBABA          ΔBABA       ΔBABA
# ΔFB                                        0.456371       0.030571   14.928102
# (Lag 1, Residual(BABA - β·FB))            -0.031365       0.009481   -3.308126

# %%
model.p_value < 0.05
# Out:
#                                 ΔBABA
# ΔFB                              True
# (Lag 1, Residual(BABA - β·FB))   True

# %% [markdown]
# # FB - BABA signal generating

# %%
model = LR(x = BABA, y = FB)
model.report()
# Out:
#          Estimate Coefficient SD of Estimate t-Statistic
#                            FB             FB          FB
# BABA                 0.864299       0.013810   62.585632
# constant            24.744947       2.749676    8.999223

# %%
residuals = pd.DataFrame(model.error.reshape(1,len(FB))[0],
                         index = BABA.index,
                         columns = ['Residual(FB - β·BABA)'])
residuals.head()
# Out:
#             Residual(FB - β·BABA)
# Date
# 2018-01-02              -2.053493
# 2018-01-03               0.893997
# 2018-01-04              -0.923957
# 2018-01-05              -2.716797
# 2018-01-08              -0.967018

# %%
model = VAR(residuals, lag = 1)
model.report()
# Out:
#                                 Estimate Coefficient        SD of Estimate  \
#                                Residual(FB - β·BABA) Residual(FB - β·BABA)
# (Lag_1, Residual(FB - β·BABA))              0.953556              0.011375
# constant                                    0.031963              0.163763
#
#                                          t-Statistic
#                                Residual(FB - β·BABA)
# (Lag_1, Residual(FB - β·BABA))             83.828855
# constant                                    0.195176

# %%
B = model.coef.values[0][0]
C = model.coef.values[1][0]
mu = C/(1-B)
tau = 1/252
SSE = np.sum(model.error**2)
sigma_eq = ((SSE*tau/(1-B**2))**0.5).values[0]

# %% [markdown]
# # Z = 1

# %%
Z = 1
upper_bound = mu +  Z * sigma_eq
lower_bound = mu -  Z * sigma_eq
print("mu: {:18f} \nupper bound: {} \nlower bound: {}".format(mu, upper_bound, lower_bound))

residuals.plot(figsize = (18,7),
              color = 'black',alpha = 0.7,
              fontsize = 12,linewidth = 1)
plt.plot(np.ones(len(residuals))*mu,
        color = '#66ffb3', label = 'mean: '+ str(mu))

plt.plot(np.ones(len(residuals))*(mu+Z*sigma_eq),
         '--', color = '#E64848', label = 'upper bound: '+str(mu+Z*sigma_eq))
plt.plot(np.ones(len(residuals))*(mu-Z*sigma_eq),
         '--',color = '#E64848', label = 'lower bound: '+str(mu-Z*sigma_eq))
plt.legend(fontsize = 9)

plt.title('Signals (Z = {})'.format(Z),
          color = '#E64848',
         fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Signals (Z = 1)')

# %%
from utility import Backtest
df = pd.read_csv(datafile, index_col = 'Date')
df['res_past'] = residuals.shift().fillna(0)
df['res'] = residuals
test = Backtest(df,upper_bound, lower_bound, mu)
trading_rec = test.Signal_generation(daily=False)
test.PL(trading_rec, beta = 0.864299)
# Out:
# ====================Cumulative Profit====================
# 0     30.532383
# 1     73.419449
# 2    104.523171
# 3    131.573661
# 4    162.453535
# 5    203.895589
# 6    231.321956
# 7    262.797841
# dtype: float64

# %%
trading_rec
# Out:
#                   BABA          FB   res_past        res  action
# Date
# 2018-03-20  198.949997  168.149994 -20.317073 -28.547278  entry2
# 2018-06-21  202.210007  201.500000  -0.989369   1.985104    exit
# 2018-07-24  189.000000  214.669998  24.506539  26.572501  entry1
# 2018-07-26  194.179993  176.259995  21.641100 -16.314566    exit
# 2018-11-27  156.460007  135.000000 -23.204257 -24.973207  entry2
# 2019-04-25  187.880005  193.259995  -2.639378   6.130508    exit
# 2019-05-30  151.070007  183.009995  25.656716  27.695360  entry1
# 2019-12-11  204.639999  202.259995   2.876275   0.644858    exit
# 2020-03-09  197.660004  169.500000 -20.525140 -26.082332  entry2
# 2020-04-30  202.669998  204.710007  -9.205588   4.797541    exit
# 2020-05-22  199.699997  234.910004  23.275329  37.564507  entry1
# 2020-07-08  257.679993  243.580002  11.699653  -3.877559    exit
# 2020-08-07  252.100006  268.440002  10.908045  25.805220  entry1
# 2020-09-16  278.140015  263.519989   7.434466  -1.621152    exit
# 2020-10-16  307.309998  265.929993 -16.847979 -24.422742  entry2
# 2020-11-04  295.709991  287.380005  -6.262890   7.053146    exit
# 2020-11-13  260.839996  276.950012  21.892118  26.761263  entry1

# %%
trading_d_rec = test.Signal_generation()
trading_d_rec = test.Returns(trading_d_rec, beta = 0.864299)
test.plot(trading_d_rec)

# %%
# Rolling Beta

# %%
sp = pd.read_csv('SP500.csv',index_col = 'Date')
sp
# Out:
#                   SP500  SP500 Ret  Port Ret  Rolling_beta_1_week  \
# Date
# 2018-03-21  2711.929932  -0.000802  0.023351                  NaN
# 2018-03-22  2643.689941  -0.011068  0.021540                  NaN
# 2018-03-23  2588.260010  -0.009203 -0.017623                  NaN
# 2018-03-26  2658.550049   0.011637 -0.039064                  NaN
# 2018-03-27  2612.620117  -0.007569 -0.010248                  NaN
# ...                 ...        ...       ...                  ...
# 2020-11-20  3557.540039  -0.002960  0.047292             0.077463
# 2020-11-23  3577.590088   0.002441  0.002707             0.035353
# 2020-11-24  3635.409912   0.006963 -0.000182             0.060995
# 2020-11-25  3629.649902  -0.000689 -0.002129             0.000345
# 2020-11-27  3638.350098   0.001040 -0.011891            -0.127191
#
#             Rolling_beta_2_week  Rolling_1_month
# Date
# 2018-03-21                  NaN              NaN
# 2018-03-22                  NaN              NaN
# 2018-03-23                  NaN              NaN
# 2018-03-26                  NaN              NaN
# 2018-03-27                  NaN              NaN
# ...                         ...              ...
# 2020-11-20             0.113727         0.090500
# 2020-11-23             0.108479         0.080722
# 2020-11-24             0.108450         0.077760
# 2020-11-25             0.104539         0.093040
# 2020-11-27             0.095229         0.085156
#
# [421 rows x 6 columns]

# %%
sp[['Rolling_beta_1_week','Rolling_beta_2_week','Rolling_1_month']].plot(figsize = (12,6))
plt.grid(True)

# %% [markdown]
# # z = 1.03

# %%
#1.03
Z = 1.03
upper_bound = mu +  Z * sigma_eq
lower_bound = mu -  Z * sigma_eq
print("mu: {:18f} \nupper bound: {} \nlower bound: {}".format(mu, upper_bound, lower_bound))

residuals.plot(figsize = (18,7),
              color = 'black',alpha = 0.7,
              fontsize = 12,linewidth = 1)
plt.plot(np.ones(len(residuals))*mu,
        color = '#66ffb3', label = 'mean: '+ str(mu))

plt.plot(np.ones(len(residuals))*(mu+Z*sigma_eq),
         '--', color = '#E64848', label = 'upper bound: '+str(mu+Z*sigma_eq))
plt.plot(np.ones(len(residuals))*(mu-Z*sigma_eq),
         '--',color = '#E64848', label = 'lower bound: '+str(mu-Z*sigma_eq))
plt.legend(fontsize = 9)

plt.title('Signals (Z = {})'.format(Z),
          color = '#E64848',
         fontsize = 15)
# Out:
# mu:           0.688203
# upper bound: 26.545325667412374
# lower bound: -25.168920663457317
# Text(0.5, 1.0, 'Signals (Z = 1.03)')

# %%
df = pd.read_csv(datafile, index_col = 'Date')
df['res_past'] = residuals.shift().fillna(0)
df['res'] = residuals
test = Backtest(df,upper_bound, lower_bound, mu)
trading_rec = test.Signal_generation(daily=False)
test.PL(trading_rec, beta = 0.864299)
# Out:
# ====================Cumulative Profit====================
# 0     30.532383
# 1     73.419449
# 2    105.252348
# 3    132.302839
# 4    163.182712
# 5    204.624766
# 6    233.070189
# 7    267.330199
# dtype: float64

# %%
trading_d_rec = test.Signal_generation()
trading_d_rec = test.Returns(trading_d_rec, beta = 0.864299)
test.plot(trading_d_rec)

# %% [markdown]
# # z = 0.3

# %%
Z = 0.3
upper_bound = mu +  Z * sigma_eq
lower_bound = mu -  Z * sigma_eq
print("mu: {:18f} \nupper bound: {} \nlower bound: {}".format(mu, upper_bound, lower_bound))

residuals.plot(figsize = (18,7),
              color = 'black',alpha = 0.7,
              fontsize = 12,linewidth = 1)
plt.plot(np.ones(len(residuals))*mu,
        color = '#66ffb3', label = 'mean: '+ str(mu))

plt.plot(np.ones(len(residuals))*(mu+Z*sigma_eq),
         '--', color = '#E64848', label = 'upper bound: '+str(mu+Z*sigma_eq))
plt.plot(np.ones(len(residuals))*(mu-Z*sigma_eq),
         '--',color = '#E64848', label = 'lower bound: '+str(mu-Z*sigma_eq))
plt.legend(fontsize = 9)

plt.title('Signals (Z = {})'.format(Z),
          color = '#E64848',
         fontsize = 15)
# Out:
# mu:           0.688203
# upper bound: 8.219403423948842
# lower bound: -6.842998419993785
# Text(0.5, 1.0, 'Signals (Z = 0.3)')

# %%
df = pd.read_csv(datafile, index_col = 'Date')
df['res_past'] = residuals.shift().fillna(0)
df['res'] = residuals
test = Backtest(df,upper_bound, lower_bound, mu)
trading_rec = test.Signal_generation(daily=False)
test.PL(trading_rec, beta = 0.864299)
# Out:
# ====================Cumulative Profit====================
# 0       9.258398
# 1      18.659219
# 2      31.167449
# 3      56.292915
# 4      72.043069
# 5      79.861163
# 6      89.657493
# 7      99.499108
# 8     108.874270
# 9     119.189966
# 10    131.946277
# 11    145.259974
# 12    167.073263
# 13    179.602458
# 14    194.885127
# dtype: float64

# %%
trading_d_rec = test.Signal_generation()
trading_d_rec
trading_d_rec = test.Returns(trading_d_rec, beta = 0.864299)
test.plot(trading_d_rec)
pd.DataFrame(trading_d_rec.returns).to_csv('ret_z03.csv')

# %% [markdown]
# # Rolling Beta_coint

# %%
datafile = 'data2.csv'
coint_prices = pd.read_csv(datafile,index_col = 'Date')
coint_prices.tail(10)
# Out:
#                   BABA          FB
# Date
# 2020-12-16  261.890015  275.670013
# 2020-12-17  264.429993  274.480011
# 2020-12-18  260.000000  276.399994
# 2020-12-21  260.429993  272.790009
# 2020-12-22  255.830002  267.089996
# 2020-12-23  256.179993  268.109985
# 2020-12-24  222.000000  267.399994
# 2020-12-28  222.360001  277.000000
# 2020-12-29  236.259995  276.779999
# 2020-12-30  238.389999  271.869995

# %%
coint_prices = pd.read_csv(datafile, index_col = 'Date')
FB = pd.DataFrame(coint_prices['FB'])
BABA = pd.DataFrame(coint_prices['BABA'])

# %%
model = LR(x = BABA, y = FB) 
model.report()
# Out:
#          Estimate Coefficient SD of Estimate t-Statistic
#                            FB             FB          FB
# BABA                 0.894459       0.014181   63.076613
# constant            19.816957       2.852997    6.946013

# %%
residuals = pd.DataFrame(model.error.reshape(1,len(FB))[0],
                         index = BABA.index,
                         columns = ['Residual(FB - β·BABA)'])
residuals.plot(figsize = (16,6),
              color = 'black',alpha = 0.7,
              fontsize = 12,linewidth = 1)
plt.title('Residual(FB - β·BABA)',
         color = '#E64848',
         fontsize = 15)
plt.grid(True)

# %%
adf_test = ADF(residuals)
adf_test.report()
# Out:
# The T-value is [-4.04219767] which is lower than -3.45
# [*]We reject the  𝐻0  hypothesis of unit root. The residuals are stationary.
# <style  type="text/css" >
#     #T_fd619c1c_516d_11eb_9d01_9801a7d858a3row0_col0 {
#             color:  black;
#         }    #T_fd619c1c_516d_11eb_9d01_9801a7d858a3row0_col1 {
#             color:  black;
#         }    #T_fd619c1c_516d_11eb_9d01_9801a7d858a3row0_col2 {
#             color:  red;
#         }    #T_fd619c1c_516d_11eb_9d01_9801a7d858a3row1_col0 {
#             color:  black;
#         }    #T_fd619c1c_516d_11eb_9d01_9801a7d858a3row1_col1 {
#             color:  black;
#         }    #T_fd619c1c_516d_11eb_9d01_9801a7d858a3row1_col2 {
#             color:  black;
#         }    #T_fd619c1c_516d_11eb_9d01_9801a7d858a3row2_col0 {
#             color:  black;
#         }    #T_fd619c1c_516d_11eb_9d01_9801a7d858a3row2_col1 {
#             color:  black;
#         }    #T_fd619c1c_516d_11eb_9d01_9801a7d858a3row2_col2 {
#             color:  black;
#         }</style><table id="T_fd619c1c_516d_11eb_9d01_9801a7d858a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Estimate Coefficient</th>        <th class="col_heading level0 col1" >SD of Estimate</th>        <th class="col_heading level0 col2" >t-Statistic</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >(ΔResidual(FB - β·BABA))</th>        <th class="col_heading level1 col1" >(ΔResidual(FB - β·BABA))</th>        <th class="col_heading level1 col2" >(ΔResidual(FB - β·BABA))</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fd619c1c_516d_11eb_9d01_9801a7d858a3level0_row0" class="row_heading level0 row0" >(Lag 1, Residual(FB - β·BABA))</th>
#                         <td id="T_fd619c1c_516d_11eb_9d01_9801a7d858a3row0_col0" class="data row0 col0" >-0.046338</td>
#                         <td id="T_fd619c1c_516d_11eb_9d01_9801a7d858a3row0_col1" class="data row0 col1" >0.011464</td>
#                         <td id="T_fd619c1c_516d_11eb_9d01_9801a7d858a3row0_col2" class="data row0 col2" >-4.042198</td>
#             </tr>
#             <tr>
#                         <th id="T_fd619c1c_516d_11eb_9d01_9801a7d858a3level0_row1" class="row_heading level0 row1" >(Lag 1, ΔResidual(FB - β·BABA))</th>
#                         <td id="T_fd619c1c_516d_11eb_9d01_9801a7d858a3row1_col0" class="data row1 col0" >0.059493</td>
#                         <td id="T_fd619c1c_516d_11eb_9d01_9801a7d858a3row1_col1" class="data row1 col1" >0.037226</td>
#                         <td id="T_fd619c1c_516d_11eb_9d01_9801a7d858a3row1_col2" class="data row1 col2" >1.598149</td>
#             </tr>
#             <tr>
#                         <th id="T_fd619c1c_516d_11eb_9d01_9801a7d858a3level0_row2" class="row_heading level0 row2" >constant</th>
#                         <td id="T_fd619c1c_516d_11eb_9d01_9801a7d858a3row2_col0" class="data row2 col0" >0.042902</td>
#                         <td id="T_fd619c1c_516d_11eb_9d01_9801a7d858a3row2_col1" class="data row2 col1" >0.172465</td>
#                         <td id="T_fd619c1c_516d_11eb_9d01_9801a7d858a3row2_col2" class="data row2 col2" >0.248759</td>
#             </tr>
#     </tbody></table>

# %%
Δy = pd.DataFrame(FB).diff().dropna().add_prefix('Δ')
Δx = pd.DataFrame(BABA).diff().dropna().add_prefix('Δ')

X = Δx.join(residuals.shift(1).dropna().add_prefix('(Lag 1, ').add_suffix(')'))

model = LR(X, Δy,add_const = False)
model.report()
# Out:
#                                Estimate Coefficient SD of Estimate t-Statistic
#                                                 ΔFB            ΔFB         ΔFB
# ΔBABA                                      0.470399       0.033576   14.009931
# (Lag 1, Residual(FB - β·BABA))            -0.036619       0.010246   -3.573904

# %%
model.p_value < 0.05
# Out:
#                                  ΔFB
# ΔBABA                           True
# (Lag 1, Residual(FB - β·BABA))  True
