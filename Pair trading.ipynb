# %%
import yfinance as yf
import numpy as np
import pandas as pd


import statsmodels
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from mystatstool import regression

# %%
#df1 = yf.download('CADUSD=X',start="2015-01-01", end="2020-11-21",)
#df1.to_csv('CADUSD.csv')
#df2 = yf.download('EURUSD=X',start="2015-01-01", end="2020-11-21", )
#df2.to_csv('EURUSD.csv')

# %%
df1 = df1.reindex(df2.index, axis = 0)
df1
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2015-01-01  0.860985  0.860985  0.860985  0.860985   0.860985       0
# 2015-01-02  0.860807  0.860956  0.852660  0.861030   0.861030       0
# 2015-01-05  0.848040  0.850268  0.846604  0.847961   0.847961       0
# 2015-01-06  0.850629  0.852442  0.848076  0.850557   0.850557       0
# 2015-01-07  0.844809  0.846597  0.842652  0.844809   0.844809       0
# ...              ...       ...       ...       ...        ...     ...
# 2020-11-16  0.761992  0.765333  0.761742  0.761986   0.761986       0
# 2020-11-17  0.764859  0.765580  0.762491  0.764801   0.764801       0
# 2020-11-18  0.763126  0.766824  0.762381  0.763068   0.763068       0
# 2020-11-19  0.764059  0.765169  0.762108  0.764281   0.764281       0
# 2020-11-20  0.764228  0.766901  0.764228  0.764193   0.764193       0
#
# [1534 rows x 6 columns]

# %%
df2
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2015-01-01  1.209863  1.209863  1.209863  1.209863   1.209863       0
# 2015-01-02  1.208868  1.208956  1.201080  1.208941   1.208941       0
# 2015-01-05  1.195500  1.197590  1.188909  1.194643   1.194643       0
# 2015-01-06  1.193830  1.197000  1.188693  1.193902   1.193902       0
# 2015-01-07  1.187479  1.190000  1.180401  1.187536   1.187536       0
# ...              ...       ...       ...       ...        ...     ...
# 2020-11-16  1.184427  1.186873  1.181474  1.184525   1.184525       0
# 2020-11-17  1.185972  1.189273  1.184553  1.185944   1.185944       0
# 2020-11-18  1.186437  1.189100  1.185115  1.186366   1.186366       0
# 2020-11-19  1.184287  1.185536  1.181740  1.184764   1.184764       0
# 2020-11-20  1.186746  1.189089  1.185185  1.186648   1.186648       0
#
# [1534 rows x 6 columns]

# %%
score, p_value, _ = coint(df1.Close, df2.Close)

# %%
p_value
# Out:
# 0.012811822309285726

# %%
df1.Close.plot()
df2.Close.plot()
