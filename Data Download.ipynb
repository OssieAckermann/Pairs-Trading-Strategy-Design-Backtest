# %%
import yfinance as yf
import numpy as np
import pandas as pd


import statsmodels
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = yf.download('FB',start="2016-01-01", end="2020-10-01",)
df1 = pd.DataFrame(df1.Close)
df2 = yf.download('BABA',start="2016-01-01", end="2020-10-01", )
df2 = pd.DataFrame(df2.Close)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df = yf.download(['FB','BABA'],start="2016-01-01", end="2020-12-01",)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df = df.Close

# %%
df.to_csv('data.csv')

# %%
score, p_value, _ = coint(df.BABA, df.FB)

# %%
p_value
# Out:
# 0.003147737736129912

# %%
df.BABA.plot(figsize = (10,8))
df.FB.plot()
